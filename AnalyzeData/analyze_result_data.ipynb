# %%
import pandas as pd

# %%
df_result = pd.read_csv('ketqua.csv')
df_result.head()
# Out:
#    STT          ID                Name   Female     Male  \
# 0    1  2400141999        PHAN THỊ DẬU  72 tuổi      NaN
# 1    2  2400172826            TRẦN NGÀ      NaN  60 tuổi
# 2    3  2400073467  VÕ HỒNG THIÊN PHÚC   8 tuổi      NaN
# 3    4  2400027112       NGÔ THỊ TUYÊN  73 tuổi      NaN
# 4    5  2400122048    NGUYỄN ĐINH MẠNH      NaN  27 tuổi
#
#                                           Address Insurance  \
# 0  Thị trấn Liên Nghĩa, Huyện Đức Trọng, Lâm Đồng         X
# 1        Xã Hiệp Thạnh, Huyện Đức Trọng, Lâm Đồng         X
# 2  Thị trấn Liên Nghĩa, Huyện Đức Trọng, Lâm Đồng         X
# 3  Thị trấn Liên Nghĩa, Huyện Đức Trọng, Lâm Đồng       NaN
# 4  Thị trấn Liên Nghĩa, Huyện Đức Trọng, Lâm Đồng       NaN
#
#                                             Diagnose      Department  \
# 0       M13.9-Viêm khớp không đặc hiệu; M79.1-Đau cơ  Khoa Khám Bệnh
# 1  E11-Bệnh đái tháo đường không phụ thuộc insuli...  Khoa Khám Bệnh
# ...

# %%
len(df_result)
# Out:
# 28670

# %%
df_1 = pd.read_csv('result/merged_dataset_final.csv')
len(df_1)
# Out:
# 28670

# %%
df_2 = pd.read_csv('result/merged_dataset_matched_only.csv')
len(df_2)
# Out:
# 16897

# %%
df_1.head()
# Out:
#    STT          ID                Name   Female     Male  \
# 0    1  2400141999        PHAN THỊ DẬU  72 tuổi      NaN
# 1    2  2400172826            TRẦN NGÀ      NaN  60 tuổi
# 2    3  2400073467  VÕ HỒNG THIÊN PHÚC   8 tuổi      NaN
# 3    4  2400027112       NGÔ THỊ TUYÊN  73 tuổi      NaN
# 4    5  2400122048    NGUYỄN ĐINH MẠNH      NaN  27 tuổi
#
#                                           Address Insurance  \
# 0  Thị trấn Liên Nghĩa, Huyện Đức Trọng, Lâm Đồng         X
# 1        Xã Hiệp Thạnh, Huyện Đức Trọng, Lâm Đồng         X
# 2  Thị trấn Liên Nghĩa, Huyện Đức Trọng, Lâm Đồng         X
# 3  Thị trấn Liên Nghĩa, Huyện Đức Trọng, Lâm Đồng       NaN
# 4  Thị trấn Liên Nghĩa, Huyện Đức Trọng, Lâm Đồng       NaN
#
#                                             Diagnose      Department  \
# 0       M13.9-Viêm khớp không đặc hiệu; M79.1-Đau cơ  Khoa Khám Bệnh
# 1  E11-Bệnh đái tháo đường không phụ thuộc insuli...  Khoa Khám Bệnh
# ...

# %%
df_3 = pd.read_csv('result2/debug_match_quality.csv')
# Plot histogram of match_score
import matplotlib.pyplot as plt
plt.hist(df_3['match_score'], bins=20, edgecolor='black')
plt.title('Histogram of Match Scores')
plt.xlabel('Match Score')
plt.ylabel('Frequency')
plt.show()
